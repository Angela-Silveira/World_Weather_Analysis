# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key
from datetime import datetime
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
lat_lngs = zip(lats, lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["main"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | paragominas
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | deniliquin
# Processing Record 5 of Set 1 | chokurdakh
# Processing Record 6 of Set 1 | tautira
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | coquimbo
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | auki
# Processing Record 14 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 1 | pangai
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | cidreira
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | bitung
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | fort-shevchenko
# Processing Record 23 of Set 1 | basco
# Processing Record 24 of Set 1 | vagay
# Processing Record 25 of Set 1 | rocha
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | havre-saint-pierre
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | nome
# Processing Record 31 of Set 1 | cardenas
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | pisco
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | kamaishi
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | aykhal
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | virginia beach
# Processing Record 42 of Set 1 | manjeri
# Processing Record 43 of Set 1 | issoudun
# Processing Record 44 of Set 1 | skjervoy
# Processing Record 45 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | kaeo
# Processing Record 1 of Set 2 | angoram
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | marzuq
# Processing Record 4 of Set 2 | elizabeth city
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | nikolskoye
# Processing Record 10 of Set 2 | klaksvik
# Processing Record 11 of Set 2 | buin
# Processing Record 12 of Set 2 | kotelnich
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | saint anthony
# Processing Record 16 of Set 2 | wilmington island
# Processing Record 17 of Set 2 | borlange
# City not found. Skipping...
# Processing Record 18 of Set 2 | ninohe
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | mairana
# Processing Record 21 of Set 2 | san remo
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | sikonge
# Processing Record 24 of Set 2 | kiruna
# Processing Record 25 of Set 2 | namatanai
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | pirogovo
# Processing Record 30 of Set 2 | berlevag
# Processing Record 31 of Set 2 | cayenne
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | clyde river
# Processing Record 35 of Set 2 | port-gentil
# Processing Record 36 of Set 2 | hohhot
# Processing Record 37 of Set 2 | kobojango
# City not found. Skipping...
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | tsumeb
# Processing Record 40 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | san quintin
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | awbari
# Processing Record 45 of Set 2 | srednekolymsk
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | yar-sale
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 3 | manthani
# Processing Record 2 of Set 3 | fairbanks
# Processing Record 3 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | palu
# Processing Record 7 of Set 3 | druzhba
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | punta arenas
# Processing Record 10 of Set 3 | tura
# Processing Record 11 of Set 3 | bathsheba
# Processing Record 12 of Set 3 | singaraja
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | shambu
# Processing Record 15 of Set 3 | faranah
# Processing Record 16 of Set 3 | puerto rondon
# Processing Record 17 of Set 3 | belmonte
# Processing Record 18 of Set 3 | bada
# Processing Record 19 of Set 3 | buraydah
# Processing Record 20 of Set 3 | kibala
# Processing Record 21 of Set 3 | requena
# Processing Record 22 of Set 3 | namibe
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 3 | presidente medici
# Processing Record 26 of Set 3 | timra
# Processing Record 27 of Set 3 | la libertad
# Processing Record 28 of Set 3 | zhezkazgan
# Processing Record 29 of Set 3 | joao pessoa
# Processing Record 30 of Set 3 | prizren
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | preobrazheniye
# Processing Record 33 of Set 3 | coihaique
# Processing Record 34 of Set 3 | chalisgaon
# Processing Record 35 of Set 3 | kelvington
# Processing Record 36 of Set 3 | ust-kuyga
# Processing Record 37 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 3 | vaini
# Processing Record 39 of Set 3 | praia
# Processing Record 40 of Set 3 | sur
# Processing Record 41 of Set 3 | high level
# Processing Record 42 of Set 3 | sorong
# Processing Record 43 of Set 3 | brandon
# Processing Record 44 of Set 3 | san cristobal
# Processing Record 45 of Set 3 | saldanha
# Processing Record 46 of Set 3 | port alfred
# Processing Record 47 of Set 3 | pacific grove
# Processing Record 48 of Set 3 | alice springs
# Processing Record 49 of Set 3 | nemuro
# Processing Record 50 of Set 3 | ugoofaaru
# Processing Record 1 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 4 | porto novo
# Processing Record 3 of Set 4 | swakopmund
# Processing Record 4 of Set 4 | aasiaat
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | zyryanovsk
# Processing Record 7 of Set 4 | tingo maria
# Processing Record 8 of Set 4 | kachug
# Processing Record 9 of Set 4 | guiglo
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | busayra
# Processing Record 12 of Set 4 | salina
# Processing Record 13 of Set 4 | shelburne
# Processing Record 14 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | jiazi
# Processing Record 18 of Set 4 | ketchikan
# Processing Record 19 of Set 4 | coahuayana
# Processing Record 20 of Set 4 | vao
# Processing Record 21 of Set 4 | comodoro rivadavia
# Processing Record 22 of Set 4 | bonthe
# Processing Record 23 of Set 4 | letterkenny
# Processing Record 24 of Set 4 | saint-pierre
# Processing Record 25 of Set 4 | pak phanang
# Processing Record 26 of Set 4 | miyako
# Processing Record 27 of Set 4 | castro
# Processing Record 28 of Set 4 | kerrobert
# Processing Record 29 of Set 4 | severobaykalsk
# Processing Record 30 of Set 4 | westlock
# Processing Record 31 of Set 4 | hakui
# Processing Record 32 of Set 4 | anadyr
# Processing Record 33 of Set 4 | georgetown
# Processing Record 34 of Set 4 | mersing
# Processing Record 35 of Set 4 | talaya
# Processing Record 36 of Set 4 | lompoc
# Processing Record 37 of Set 4 | calamar
# Processing Record 38 of Set 4 | mecca
# Processing Record 39 of Set 4 | upernavik
# Processing Record 40 of Set 4 | nabire
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | mareeba
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | fuxin
# Processing Record 45 of Set 4 | mitsamiouli
# Processing Record 46 of Set 4 | pangody
# Processing Record 47 of Set 4 | igmaya-an
# Processing Record 48 of Set 4 | muros
# Processing Record 49 of Set 4 | neuquen
# Processing Record 50 of Set 4 | shimoda
# Processing Record 1 of Set 5 | nieuw amsterdam
# Processing Record 2 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | bredasdorp
# Processing Record 5 of Set 5 | sitka
# Processing Record 6 of Set 5 | samarai
# Processing Record 7 of Set 5 | salalah
# Processing Record 8 of Set 5 | iqaluit
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | beeville
# Processing Record 11 of Set 5 | sombrio
# Processing Record 12 of Set 5 | merauke
# Processing Record 13 of Set 5 | melo
# Processing Record 14 of Set 5 | roald
# Processing Record 15 of Set 5 | abu samrah
# Processing Record 16 of Set 5 | sokoni
# Processing Record 17 of Set 5 | yalutorovsk
# Processing Record 18 of Set 5 | kupang
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | mangan
# Processing Record 21 of Set 5 | alofi
# Processing Record 22 of Set 5 | narsaq
# Processing Record 23 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 24 of Set 5 | evensk
# Processing Record 25 of Set 5 | kavieng
# Processing Record 26 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 27 of Set 5 | padang
# Processing Record 28 of Set 5 | anzio
# Processing Record 29 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | japura
# Processing Record 32 of Set 5 | urengoy
# Processing Record 33 of Set 5 | lebu
# Processing Record 34 of Set 5 | andevoranto
# City not found. Skipping...
# Processing Record 35 of Set 5 | kedrovyy
# Processing Record 36 of Set 5 | grants
# Processing Record 37 of Set 5 | sumbawanga
# Processing Record 38 of Set 5 | beloha
# Processing Record 39 of Set 5 | jiwani
# Processing Record 40 of Set 5 | santa barbara
# Processing Record 41 of Set 5 | yerbogachen
# Processing Record 42 of Set 5 | kalnibolotskaya
# Processing Record 43 of Set 5 | khlung
# Processing Record 44 of Set 5 | chipinge
# Processing Record 45 of Set 5 | airai
# Processing Record 46 of Set 5 | agha jari
# City not found. Skipping...
# Processing Record 47 of Set 5 | ahipara
# Processing Record 48 of Set 5 | lethem
# Processing Record 49 of Set 5 | akdepe
# Processing Record 50 of Set 5 | sorland
# Processing Record 1 of Set 6 | solnechnyy
# Processing Record 2 of Set 6 | coro
# Processing Record 3 of Set 6 | kajaani
# Processing Record 4 of Set 6 | gornopravdinsk
# Processing Record 5 of Set 6 | fukue
# Processing Record 6 of Set 6 | aklavik
# Processing Record 7 of Set 6 | lagoa
# Processing Record 8 of Set 6 | harper
# Processing Record 9 of Set 6 | camacha
# Processing Record 10 of Set 6 | pokosnoye
# Processing Record 11 of Set 6 | egvekinot
# Processing Record 12 of Set 6 | umm lajj
# Processing Record 13 of Set 6 | birin
# Processing Record 14 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 6 | zdvinsk
# Processing Record 16 of Set 6 | jakar
# Processing Record 17 of Set 6 | bojonegoro
# Processing Record 18 of Set 6 | atagay
# Processing Record 19 of Set 6 | taksimo
# Processing Record 20 of Set 6 | iberia
# Processing Record 21 of Set 6 | lagdo
# Processing Record 22 of Set 6 | tomado
# Processing Record 23 of Set 6 | vitim
# Processing Record 24 of Set 6 | mount gambier
# Processing Record 25 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 6 | port augusta
# Processing Record 28 of Set 6 | kirakira
# Processing Record 29 of Set 6 | kindu
# Processing Record 30 of Set 6 | sisimiut
# Processing Record 31 of Set 6 | whitehorse
# Processing Record 32 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 6 | bac lieu
# Processing Record 34 of Set 6 | port hedland
# Processing Record 35 of Set 6 | braganca
# Processing Record 36 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 6 | businga
# Processing Record 38 of Set 6 | saint-philippe
# Processing Record 39 of Set 6 | sumbe
# Processing Record 40 of Set 6 | provideniya
# Processing Record 41 of Set 6 | wanning
# Processing Record 42 of Set 6 | eyl
# Processing Record 43 of Set 6 | luderitz
# Processing Record 44 of Set 6 | ponta do sol
# Processing Record 45 of Set 6 | yellowknife
# Processing Record 46 of Set 6 | vardo
# Processing Record 47 of Set 6 | richards bay
# Processing Record 48 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 6 | zabkowice slaskie
# Processing Record 50 of Set 6 | burica
# City not found. Skipping...
# Processing Record 1 of Set 7 | pevek
# Processing Record 2 of Set 7 | siloam springs
# Processing Record 3 of Set 7 | hambantota
# Processing Record 4 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 5 of Set 7 | yulara
# Processing Record 6 of Set 7 | baruun-urt
# Processing Record 7 of Set 7 | diu
# Processing Record 8 of Set 7 | hami
# Processing Record 9 of Set 7 | mashhad
# Processing Record 10 of Set 7 | akureyri
# Processing Record 11 of Set 7 | bianzhuang
# Processing Record 12 of Set 7 | kimbe
# Processing Record 13 of Set 7 | haines junction
# Processing Record 14 of Set 7 | koungheul
# Processing Record 15 of Set 7 | ukiah
# Processing Record 16 of Set 7 | porto nacional
# Processing Record 17 of Set 7 | cockburn town
# Processing Record 18 of Set 7 | bubaque
# Processing Record 19 of Set 7 | kawerau
# Processing Record 20 of Set 7 | del rio
# Processing Record 21 of Set 7 | mokhsogollokh
# Processing Record 22 of Set 7 | kasempa
# Processing Record 23 of Set 7 | belyy yar
# Processing Record 24 of Set 7 | esso
# Processing Record 25 of Set 7 | baft
# Processing Record 26 of Set 7 | dicabisagan
# Processing Record 27 of Set 7 | narrabri
# Processing Record 28 of Set 7 | la ronge
# Processing Record 29 of Set 7 | bluefield
# Processing Record 30 of Set 7 | sakakah
# Processing Record 31 of Set 7 | sambava
# Processing Record 32 of Set 7 | makakilo city
# Processing Record 33 of Set 7 | saskylakh
# Processing Record 34 of Set 7 | mikhaylovka
# Processing Record 35 of Set 7 | kedougou
# Processing Record 36 of Set 7 | mount isa
# Processing Record 37 of Set 7 | salinopolis
# Processing Record 38 of Set 7 | stornoway
# Processing Record 39 of Set 7 | portland
# Processing Record 40 of Set 7 | jalu
# Processing Record 41 of Set 7 | mechetinskaya
# Processing Record 42 of Set 7 | katsuura
# Processing Record 43 of Set 7 | peniche
# Processing Record 44 of Set 7 | goderich
# Processing Record 45 of Set 7 | mahebourg
# Processing Record 46 of Set 7 | lai
# Processing Record 47 of Set 7 | port lincoln
# Processing Record 48 of Set 7 | anshun
# Processing Record 49 of Set 7 | isabela
# Processing Record 50 of Set 7 | mapiripan
# Processing Record 1 of Set 8 | plainview
# Processing Record 2 of Set 8 | batagay-alyta
# Processing Record 3 of Set 8 | aromashevo
# Processing Record 4 of Set 8 | keti bandar
# Processing Record 5 of Set 8 | fremont
# Processing Record 6 of Set 8 | cuamba
# Processing Record 7 of Set 8 | gizo
# Processing Record 8 of Set 8 | laguna
# Processing Record 9 of Set 8 | baishishan
# Processing Record 10 of Set 8 | acapulco
# Processing Record 11 of Set 8 | machiques
# Processing Record 12 of Set 8 | charters towers
# Processing Record 13 of Set 8 | borazjan
# Processing Record 14 of Set 8 | progreso
# Processing Record 15 of Set 8 | tiksi
# Processing Record 16 of Set 8 | leshukonskoye
# Processing Record 17 of Set 8 | kungurtug
# Processing Record 18 of Set 8 | antofagasta
# Processing Record 19 of Set 8 | moose factory
# Processing Record 20 of Set 8 | beberibe
# Processing Record 21 of Set 8 | almeirim
# Processing Record 22 of Set 8 | yumen
# Processing Record 23 of Set 8 | vila
# Processing Record 24 of Set 8 | te anau
# Processing Record 25 of Set 8 | pangnirtung
# Processing Record 26 of Set 8 | souillac
# Processing Record 27 of Set 8 | granville
# Processing Record 28 of Set 8 | ballina
# Processing Record 29 of Set 8 | sitio novo do tocantins
# Processing Record 30 of Set 8 | rawson
# Processing Record 31 of Set 8 | amahai
# Processing Record 32 of Set 8 | viedma
# Processing Record 33 of Set 8 | townsville
# Processing Record 34 of Set 8 | kastamonu
# Processing Record 35 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 8 | juneau
# Processing Record 37 of Set 8 | husavik
# Processing Record 38 of Set 8 | aban
# Processing Record 39 of Set 8 | cabedelo
# Processing Record 40 of Set 8 | cassano delle murge
# Processing Record 41 of Set 8 | fortuna foothills
# Processing Record 42 of Set 8 | vaitape
# Processing Record 43 of Set 8 | vostok
# Processing Record 44 of Set 8 | hasaki
# Processing Record 45 of Set 8 | vorsma
# Processing Record 46 of Set 8 | deer lake
# Processing Record 47 of Set 8 | hargeysa
# Processing Record 48 of Set 8 | asau
# Processing Record 49 of Set 8 | koumac
# Processing Record 50 of Set 8 | coolum beach
# Processing Record 1 of Set 9 | bowen
# Processing Record 2 of Set 9 | fuerte olimpo
# Processing Record 3 of Set 9 | mochumi
# Processing Record 4 of Set 9 | sechura
# Processing Record 5 of Set 9 | marsa matruh
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | wonthaggi
# Processing Record 8 of Set 9 | okha
# Processing Record 9 of Set 9 | vega de alatorre
# Processing Record 10 of Set 9 | bagdarin
# Processing Record 11 of Set 9 | colac
# Processing Record 12 of Set 9 | gerash
# Processing Record 13 of Set 9 | praia da vitoria
# Processing Record 14 of Set 9 | dhidhdhoo
# Processing Record 15 of Set 9 | sazonovo
# Processing Record 16 of Set 9 | guerrero negro
# Processing Record 17 of Set 9 | bengkulu
# Processing Record 18 of Set 9 | oyama
# Processing Record 19 of Set 9 | vila velha
# Processing Record 20 of Set 9 | gigmoto
# Processing Record 21 of Set 9 | karratha
# Processing Record 22 of Set 9 | caravelas
# Processing Record 23 of Set 9 | mackay
# Processing Record 24 of Set 9 | devonport
# Processing Record 25 of Set 9 | seguela
# Processing Record 26 of Set 9 | cordoba
# Processing Record 27 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 9 | ossora
# Processing Record 29 of Set 9 | xuddur
# Processing Record 30 of Set 9 | meru
# Processing Record 31 of Set 9 | port macquarie
# Processing Record 32 of Set 9 | svetlogorsk
# Processing Record 33 of Set 9 | quatre cocos
# Processing Record 34 of Set 9 | lokoja
# Processing Record 35 of Set 9 | tadine
# Processing Record 36 of Set 9 | mago
# Processing Record 37 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 9 | tual
# Processing Record 39 of Set 9 | taybad
# Processing Record 40 of Set 9 | tateyama
# Processing Record 41 of Set 9 | san luis
# Processing Record 42 of Set 9 | menongue
# Processing Record 43 of Set 9 | halifax
# Processing Record 44 of Set 9 | fortuna
# Processing Record 45 of Set 9 | guapo
# Processing Record 46 of Set 9 | teguise
# Processing Record 47 of Set 9 | dinguiraye
# Processing Record 48 of Set 9 | sao gabriel da cachoeira
# Processing Record 49 of Set 9 | bankura
# Processing Record 50 of Set 9 | mehamn
# Processing Record 1 of Set 10 | tuntum
# Processing Record 2 of Set 10 | san patricio
# Processing Record 3 of Set 10 | paamiut
# Processing Record 4 of Set 10 | mbigou
# Processing Record 5 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 10 | dipolog
# Processing Record 7 of Set 10 | placido de castro
# Processing Record 8 of Set 10 | tiznit
# Processing Record 9 of Set 10 | dingle
# Processing Record 10 of Set 10 | zemio
# Processing Record 11 of Set 10 | kutum
# Processing Record 12 of Set 10 | kissamos
# Processing Record 13 of Set 10 | tabou
# Processing Record 14 of Set 10 | masuguru
# Processing Record 15 of Set 10 | broome
# Processing Record 16 of Set 10 | santa maria
# Processing Record 17 of Set 10 | zhuhai
# Processing Record 18 of Set 10 | iralaya
# Processing Record 19 of Set 10 | northam
# Processing Record 20 of Set 10 | tessalit
# Processing Record 21 of Set 10 | ambilobe
# Processing Record 22 of Set 10 | dawei
# Processing Record 23 of Set 10 | champerico
# Processing Record 24 of Set 10 | batagay
# Processing Record 25 of Set 10 | lasa
# Processing Record 26 of Set 10 | ojinaga
# Processing Record 27 of Set 10 | kenai
# Processing Record 28 of Set 10 | ostrovnoy
# Processing Record 29 of Set 10 | saint-louis
# Processing Record 30 of Set 10 | taoudenni
# Processing Record 31 of Set 10 | krasnyy chikoy
# Processing Record 32 of Set 10 | hay river
# Processing Record 33 of Set 10 | laviana
# Processing Record 34 of Set 10 | rudnichnyy
# Processing Record 35 of Set 10 | liwale
# Processing Record 36 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 10 | lata
# Processing Record 39 of Set 10 | kempele
# Processing Record 40 of Set 10 | hofn
# Processing Record 41 of Set 10 | faanui
# Processing Record 42 of Set 10 | san jeronimo
# Processing Record 43 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 44 of Set 10 | ayagoz
# Processing Record 45 of Set 10 | saint-augustin
# Processing Record 46 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 10 | katangli
# Processing Record 48 of Set 10 | san rafael
# Processing Record 49 of Set 10 | malinovoye ozero
# Processing Record 50 of Set 10 | dudinka
# Processing Record 1 of Set 11 | bayanday
# Processing Record 2 of Set 11 | cozumel
# Processing Record 3 of Set 11 | deh rawud
# City not found. Skipping...
# Processing Record 4 of Set 11 | bella vista
# Processing Record 5 of Set 11 | vanderhoof
# Processing Record 6 of Set 11 | iguape
# Processing Record 7 of Set 11 | parau
# Processing Record 8 of Set 11 | voronovytsya
# Processing Record 9 of Set 11 | bilibino
# Processing Record 10 of Set 11 | north bend
# Processing Record 11 of Set 11 | kavaratti
# Processing Record 12 of Set 11 | iskateley
# Processing Record 13 of Set 11 | laurel
# Processing Record 14 of Set 11 | pustoshka
# Processing Record 15 of Set 11 | port hardy
# Processing Record 16 of Set 11 | dzaoudzi
# Processing Record 17 of Set 11 | khandyga
# Processing Record 18 of Set 11 | melchor de mencos
# Processing Record 19 of Set 11 | kinshasa
# Processing Record 20 of Set 11 | morondava
# Processing Record 21 of Set 11 | vila franca do campo
# Processing Record 22 of Set 11 | barrhead
# Processing Record 23 of Set 11 | nuristan
# Processing Record 24 of Set 11 | betioky
# Processing Record 25 of Set 11 | yarada
# Processing Record 26 of Set 11 | malu mare
# Processing Record 27 of Set 11 | ayan
# Processing Record 28 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 11 | aanekoski
# Processing Record 30 of Set 11 | xichang
# Processing Record 31 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 11 | pundaguitan
# Processing Record 33 of Set 11 | miri
# Processing Record 34 of Set 11 | mafeteng
# Processing Record 35 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 11 | mao
# Processing Record 37 of Set 11 | gat
# Processing Record 38 of Set 11 | zhigansk
# Processing Record 39 of Set 11 | yining
# Processing Record 40 of Set 11 | puerto baquerizo moreno
# Processing Record 41 of Set 11 | novobirilyussy
# Processing Record 42 of Set 11 | markala
# Processing Record 43 of Set 11 | port blair
# Processing Record 44 of Set 11 | nizhneudinsk
# Processing Record 45 of Set 11 | alpinopolis
# Processing Record 46 of Set 11 | bismarck
# Processing Record 47 of Set 11 | la cruz
# Processing Record 48 of Set 11 | the valley
# Processing Record 49 of Set 11 | eenhana
# Processing Record 50 of Set 11 | bristol
# Processing Record 1 of Set 12 | amazar
# Processing Record 2 of Set 12 | barroualie
# City not found. Skipping...
# Processing Record 3 of Set 12 | adeje
# Processing Record 4 of Set 12 | beirut
# Processing Record 5 of Set 12 | roma
# Processing Record 6 of Set 12 | dunedin
# Processing Record 7 of Set 12 | nuuk
# Processing Record 8 of Set 12 | sao joao da barra
# Processing Record 9 of Set 12 | shu
# Processing Record 10 of Set 12 | santarem
# Processing Record 11 of Set 12 | sitangkai
# Processing Record 12 of Set 12 | ancud
# Processing Record 13 of Set 12 | little current
# Processing Record 14 of Set 12 | ankazoabo
# Processing Record 15 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 12 | beidao
# Processing Record 17 of Set 12 | north myrtle beach
# Processing Record 18 of Set 12 | nouadhibou
# Processing Record 19 of Set 12 | santiago del estero
# Processing Record 20 of Set 12 | mbaiki
# Processing Record 21 of Set 12 | zapadnaya dvina
# Processing Record 22 of Set 12 | grand-lahou
# Processing Record 23 of Set 12 | utete
# Processing Record 24 of Set 12 | grindavik
# Processing Record 25 of Set 12 | shikarpur
# Processing Record 26 of Set 12 | doka
# Processing Record 27 of Set 12 | moroto
# Processing Record 28 of Set 12 | mahibadhoo
# Processing Record 29 of Set 12 | afzalgarh
# Processing Record 30 of Set 12 | grand gaube
# Processing Record 31 of Set 12 | road town
# Processing Record 32 of Set 12 | isangel
# Processing Record 33 of Set 12 | adrar
# Processing Record 34 of Set 12 | hamilton
# Processing Record 35 of Set 12 | isla vista
# Processing Record 36 of Set 12 | seoul
# Processing Record 37 of Set 12 | brae
# Processing Record 38 of Set 12 | kusk
# City not found. Skipping...
# Processing Record 39 of Set 12 | vezirkopru
# Processing Record 40 of Set 12 | mayo
# Processing Record 41 of Set 12 | berwick
# Processing Record 42 of Set 12 | bardiyah
# Processing Record 43 of Set 12 | kelheim
# Processing Record 44 of Set 12 | tsaghkahovit
# Processing Record 45 of Set 12 | ohara
# Processing Record 46 of Set 12 | masterton
# Processing Record 47 of Set 12 | poum
# Processing Record 48 of Set 12 | saint-francois
# Processing Record 49 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 12 | taitung
# Processing Record 1 of Set 13 | karatau
# Processing Record 2 of Set 13 | botou
# Processing Record 3 of Set 13 | baghdad
# Processing Record 4 of Set 13 | amuntai
# Processing Record 5 of Set 13 | sabzevar
# Processing Record 6 of Set 13 | urumqi
# Processing Record 7 of Set 13 | san pedro
# Processing Record 8 of Set 13 | naze
# Processing Record 9 of Set 13 | ulladulla
# Processing Record 10 of Set 13 | huarmey
# Processing Record 11 of Set 13 | krasnyy kut
# Processing Record 12 of Set 13 | mwanza
# Processing Record 13 of Set 13 | grajau
# Processing Record 14 of Set 13 | ridgecrest
# Processing Record 15 of Set 13 | flinders
# Processing Record 16 of Set 13 | hit
# Processing Record 17 of Set 13 | slave lake
# Processing Record 18 of Set 13 | kruisfontein
# Processing Record 19 of Set 13 | san juan de flores
# Processing Record 20 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 13 | khor
# Processing Record 22 of Set 13 | maunabo
# Processing Record 23 of Set 13 | tezu
# Processing Record 24 of Set 13 | iranduba
# Processing Record 25 of Set 13 | tolaga bay
# Processing Record 26 of Set 13 | riverton
# Processing Record 27 of Set 13 | sabang
# Processing Record 28 of Set 13 | kalabo
# Processing Record 29 of Set 13 | batesville
# Processing Record 30 of Set 13 | geraldton
# Processing Record 31 of Set 13 | fenoarivo atsinanana
# Processing Record 32 of Set 13 | san isidro
# Processing Record 33 of Set 13 | wattegama
# Processing Record 34 of Set 13 | birjand
# Processing Record 35 of Set 13 | okhotsk
# Processing Record 36 of Set 13 | xai-xai
# Processing Record 37 of Set 13 | ghanaur
# Processing Record 38 of Set 13 | gushikawa
# Processing Record 39 of Set 13 | sept-iles
# Processing Record 40 of Set 13 | nogliki
# Processing Record 41 of Set 13 | abu kamal
# Processing Record 42 of Set 13 | atambua
# Processing Record 43 of Set 13 | tsabong
# Processing Record 44 of Set 13 | zyryanka
# Processing Record 45 of Set 13 | panama city
# Processing Record 46 of Set 13 | olafsvik
# Processing Record 47 of Set 13 | turukhansk
# Processing Record 48 of Set 13 | ambanja
# Processing Record 49 of Set 13 | santa vitoria do palmar
# Processing Record 50 of Set 13 | lakes entrance
# Processing Record 1 of Set 14 | jatiroto
# Processing Record 2 of Set 14 | benjamin constant
# Processing Record 3 of Set 14 | demba
# Processing Record 4 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 14 | omboue
# Processing Record 6 of Set 14 | lere
# Processing Record 7 of Set 14 | nushki
# Processing Record 8 of Set 14 | tocache
# Processing Record 9 of Set 14 | mananara
# Processing Record 10 of Set 14 | concepcion del oro
# Processing Record 11 of Set 14 | buchanan
# Processing Record 12 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 14 | hokitika
# Processing Record 14 of Set 14 | wucheng
# Processing Record 15 of Set 14 | panaba
# Processing Record 16 of Set 14 | komsomolskiy
# Processing Record 17 of Set 14 | pavino
# Processing Record 18 of Set 14 | kareli
# Processing Record 19 of Set 14 | nortelandia
# Processing Record 20 of Set 14 | mumford
# Processing Record 21 of Set 14 | yuzhno-kurilsk
# Processing Record 22 of Set 14 | maun
# Processing Record 23 of Set 14 | ornskoldsvik
# Processing Record 24 of Set 14 | sangar
# Processing Record 25 of Set 14 | brentwood
# Processing Record 26 of Set 14 | carutapera
# Processing Record 27 of Set 14 | rancho palos verdes
# Processing Record 28 of Set 14 | honningsvag
# Processing Record 29 of Set 14 | qaqortoq
# Processing Record 30 of Set 14 | itigi
# Processing Record 31 of Set 14 | moussoro
# Processing Record 32 of Set 14 | kieta
# Processing Record 33 of Set 14 | zhicheng
# Processing Record 34 of Set 14 | port-cartier
# Processing Record 35 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 14 | aswan
# Processing Record 38 of Set 14 | panzhihua
# Processing Record 39 of Set 14 | novikovo
# Processing Record 40 of Set 14 | guicheng
# City not found. Skipping...
# Processing Record 41 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 14 | grafton
# Processing Record 43 of Set 14 | borogontsy
# Processing Record 44 of Set 14 | constantine
# Processing Record 45 of Set 14 | la esperanza
# Processing Record 46 of Set 14 | tahe
# Processing Record 47 of Set 14 | ternate
# Processing Record 48 of Set 14 | kuusamo
# Processing Record 49 of Set 14 | flin flon
# Processing Record 50 of Set 14 | maliq
# Processing Record 1 of Set 15 | kalmunai
# Processing Record 2 of Set 15 | manavgat
# Processing Record 3 of Set 15 | pimentel
# Processing Record 4 of Set 15 | severnyy
# Processing Record 5 of Set 15 | soyo
# Processing Record 6 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 7 of Set 15 | mandalgovi
# Processing Record 8 of Set 15 | cravo norte
# Processing Record 9 of Set 15 | moron
# Processing Record 10 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 15 | ushtobe
# Processing Record 13 of Set 15 | marfino
# Processing Record 14 of Set 15 | batasan
# Processing Record 15 of Set 15 | ilawa
# Processing Record 16 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 15 | springdale
# Processing Record 18 of Set 15 | liverpool
# Processing Record 19 of Set 15 | golden
# Processing Record 20 of Set 15 | puerto penasco
# Processing Record 21 of Set 15 | beyneu
# Processing Record 22 of Set 15 | niteroi
# Processing Record 23 of Set 15 | schneeberg
# Processing Record 24 of Set 15 | djenne
# Processing Record 25 of Set 15 | skibbereen
# Processing Record 26 of Set 15 | avera
# Processing Record 27 of Set 15 | emerald
# Processing Record 28 of Set 15 | christchurch
# Processing Record 29 of Set 15 | jacareacanga
# Processing Record 30 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 15 | zhanaozen
# Processing Record 32 of Set 15 | ivanivka
# Processing Record 33 of Set 15 | barranca
# Processing Record 34 of Set 15 | vernon
# Processing Record 35 of Set 15 | magui
# City not found. Skipping...
# Processing Record 36 of Set 15 | bilma
# Processing Record 37 of Set 15 | changping
# Processing Record 38 of Set 15 | kashi
# Processing Record 39 of Set 15 | ginda
# Processing Record 40 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 41 of Set 15 | vanimo
# Processing Record 42 of Set 15 | karachev
# Processing Record 43 of Set 15 | kumluca
# Processing Record 44 of Set 15 | cantapoy
# Processing Record 45 of Set 15 | pontes e lacerda
# Processing Record 46 of Set 15 | belaya gora
# Processing Record 47 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 15 | sao lourenco do oeste
# Processing Record 49 of Set 15 | kaberamaido
# Processing Record 50 of Set 15 | igarka
# Processing Record 1 of Set 16 | sorrento
# Processing Record 2 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 16 | nikolayevsk-na-amure
# Processing Record 4 of Set 16 | warrington
# Processing Record 5 of Set 16 | pauini
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.12 -134.97     70.02        71          40
# 1      Paragominas      BR  -2.97  -47.48     70.48        98          51
# 2  Bambous Virieux      MU -20.34   57.76     73.99        78          75
# 3       Deniliquin      AU -35.53  144.97     60.01        50           0
# 4       Chokurdakh      RU  70.63  147.92     44.64        75         100
# 5          Tautira      PF -17.73 -149.15     77.00        73          20
# 6          Mataura      NZ -46.19  168.86     45.00        72          99
# 7         Thompson      CA  55.74  -97.86     50.00       100          90
# 8         Coquimbo      CL -29.95  -71.34     50.00        87          20
# 9       Nanortalik      GL  60.14  -45.24     43.83        85           2
#
#    Wind Speed Current Weather
# 0        8.12          Clouds
# 1        2.64          Clouds
# 2        8.05          Clouds
# 3        1.01           Clear
# 4        7.25          Clouds
# 5        3.36          Clouds
# 6       11.01            Rain
# 7        8.05         Drizzle
# 8        2.24          Clouds
# 9        5.61           Clear

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
